# %%
# Student info
name: str = "Yasmeen"
roll_no: int = 40

subjects = ["English", "chemistry", "Physics", "zoology" , "botany"]
marks = [75, 50, 62, 90 , 85]

# Total & percentage
total: int = sum(marks)
percentage: int = total * 100 // (len(subjects) * 100)

# Grade
def get_grade(p: int) -> str:
    match p // 10:
        case 10 | 9:
            return "A+"
        case 8:
            return "A"
        case 7:
            return "B"
        case 6:
            return "C"
        case 5:
            return "D"
        case _:
            return "F"

# Result
def get_result(p: int) -> str:
    match p >= 40:
        case True:
            return "Pass"
        case False:
            return "Fail"

grade = get_grade(percentage)
result = get_result(percentage)

# DMC table
df = pd.DataFrame({
    "Subject": subjects,
    "Marks": marks
})

# Output
print("------ DMC ------")
print("Name:", name)
print("Roll No:", roll_no)
print(df)
print("Total:", total)
print("Percentage:", percentage)
print("Grade:", grade)
print("Result:", result)
# Out:
# ------ DMC ------
# Name: Yasmeen
# Roll No: 40
#      Subject  Marks
# 0    English     75
# 1  chemistry     50
# 2    Physics     62
# 3    zoology     90
# 4     botany     85
# Total: 362
# Percentage: 72
# Grade: B
# Result: Pass
